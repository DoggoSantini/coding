# %%
from chembl_webresource_client.new_client import new_client
import tensorflow as tf
import pandas as pd
import numpy as np
# Out:
# 2023-05-25 23:23:15.375307: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
molecules = new_client.molecule
mols = molecules.filter(molecule_properties__num_ro5_violations=0).only(['molecule_chembl_id', 'molecule_structures'])

# %%
max_length = 50
array_size = 100_000
smiles = [mol['molecule_structures']['canonical_smiles'] for mol in mols[:array_size]]
filtered_smiles = [smile for smile in smiles if len(smile) <= max_length]
print(len(mols), len(smiles), len(filtered_smiles))
# Out:
# 1631753 100000 74395

# %%
def one_hot_encoding(smiles):
    num_samples = len(smiles)

    unique_chars = list(set(''.join(smiles)))
    encoding_dim = len(unique_chars) + 1

    max_length = max([len(smile) for smile in smiles])

    input = np.zeros((num_samples, max_length, encoding_dim))

    for counter, smile in enumerate(smiles):
        for row, char in enumerate(smile):
            col = unique_chars.index(char)
            input[counter, row, col] = 1
        # pad with last basis vector
        for row in range(len(smile), max_length): 
            input[counter, col, encoding_dim-1] = 1

    input = tf.convert_to_tensor(input)

    return input, unique_chars

input, unique_chars = one_hot_encoding(filtered_smiles)

# %%
input.shape
# Out:
# TensorShape([74395, 50, 38])

# %%
train_percent = 0.9
train_cutoff = int(input.shape[0] * train_percent)
train, test = input[:train_cutoff, :, :], input[train_cutoff:, :, :]

# %%
train.shape, test.shape
# Out:
# (TensorShape([66955, 50, 38]), TensorShape([7440, 50, 38]))

# %%
class AutoEncoder(tf.keras.Model):
  def __init__(self):
    super().__init__()

    self.leakyrelualpha = 0.5
    self.dropoutrate = 0.6

    # LSTM STAGE
    self.lstm1 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, return_sequences=True))
    self.lstm2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(512))
    self.dense0 = tf.keras.layers.Dense(128, activation=tf.keras.layers.LeakyReLU(alpha=self.leakyrelualpha), kernel_regularizer=tf.keras.regularizers.L1L2(l1=1e-5, l2=1e-4), bias_regularizer=tf.keras.regularizers.L2(1e-4))

    # DIM. REDUCTION STAGE
    self.dense1 = tf.keras.layers.Dense(32, activation=tf.keras.layers.LeakyReLU(alpha=self.leakyrelualpha), kernel_regularizer=tf.keras.regularizers.L1L2(l1=1e-5, l2=1e-4), bias_regularizer=tf.keras.regularizers.L2(1e-4))
    self.dense2 = tf.keras.layers.Dense(16, activation=tf.keras.layers.LeakyReLU(alpha=self.leakyrelualpha), kernel_regularizer=tf.keras.regularizers.L1L2(l1=1e-5, l2=1e-4), bias_regularizer=tf.keras.regularizers.L2(1e-4))
    self.dense3 = tf.keras.layers.Dense(16, activation=tf.keras.layers.LeakyReLU(alpha=self.leakyrelualpha), kernel_regularizer=tf.keras.regularizers.L1L2(l1=1e-5, l2=1e-4), bias_regularizer=tf.keras.regularizers.L2(1e-4))

    # SAMPLING STAGE
    # NOT PRESENT IN THIS MODEL

    # DECODING STAGE
    self.dense4 = tf.keras.layers.Dense(16, activation=tf.keras.layers.LeakyReLU(alpha=self.leakyrelualpha), kernel_regularizer=tf.keras.regularizers.L1L2(l1=1e-5, l2=1e-4), bias_regularizer=tf.keras.regularizers.L2(1e-4))
    self.dense5 = tf.keras.layers.Dense(16, activation=tf.keras.layers.LeakyReLU(alpha=self.leakyrelualpha), kernel_regularizer=tf.keras.regularizers.L1L2(l1=1e-5, l2=1e-4), bias_regularizer=tf.keras.regularizers.L2(1e-4))
    self.dense6 = tf.keras.layers.Dense(32, activation=tf.keras.layers.LeakyReLU(alpha=self.leakyrelualpha), kernel_regularizer=tf.keras.regularizers.L1L2(l1=1e-5, l2=1e-4), bias_regularizer=tf.keras.regularizers.L2(1e-4))
    self.dense7 = tf.keras.layers.Dense(64, activation=tf.keras.layers.LeakyReLU(alpha=self.leakyrelualpha), kernel_regularizer=tf.keras.regularizers.L1L2(l1=1e-5, l2=1e-4), bias_regularizer=tf.keras.regularizers.L2(1e-4))
    self.dense8 = tf.keras.layers.Dense(128, activation=tf.keras.layers.LeakyReLU(alpha=self.leakyrelualpha), kernel_regularizer=tf.keras.regularizers.L1L2(l1=1e-5, l2=1e-4), bias_regularizer=tf.keras.regularizers.L2(1e-4))
    self.dense9 = tf.keras.layers.Dense(256, activation=tf.keras.layers.LeakyReLU(alpha=self.leakyrelualpha), kernel_regularizer=tf.keras.regularizers.L1L2(l1=1e-5, l2=1e-4), bias_regularizer=tf.keras.regularizers.L2(1e-4))
    self.dense10 = tf.keras.layers.Dense(512, activation=tf.keras.layers.LeakyReLU(alpha=self.leakyrelualpha), kernel_regularizer=tf.keras.regularizers.L1L2(l1=1e-5, l2=1e-4), bias_regularizer=tf.keras.regularizers.L2(1e-4))
    self.dense11 = tf.keras.layers.Dense(1024, activation=tf.keras.layers.LeakyReLU(alpha=self.leakyrelualpha), kernel_regularizer=tf.keras.regularizers.L1L2(l1=1e-5, l2=1e-4), bias_regularizer=tf.keras.regularizers.L2(1e-4))
    self.dense12 = tf.keras.layers.Dense(2048, activation=tf.keras.layers.LeakyReLU(alpha=self.leakyrelualpha), kernel_regularizer=tf.keras.regularizers.L1L2(l1=1e-5, l2=1e-4), bias_regularizer=tf.keras.regularizers.L2(1e-4))
    self.dense13 = tf.keras.layers.Dense(4096, activation=tf.keras.layers.LeakyReLU(alpha=self.leakyrelualpha), kernel_regularizer=tf.keras.regularizers.L1L2(l1=1e-5, l2=1e-4), bias_regularizer=tf.keras.regularizers.L2(1e-4))

    # DESIRED DIMENSIONS
    self.dense14 = tf.keras.layers.Dense(50*38, activation=tf.keras.layers.LeakyReLU(alpha=self.leakyrelualpha), kernel_regularizer=tf.keras.regularizers.L1L2(l1=1e-5, l2=1e-4), bias_regularizer=tf.keras.regularizers.L2(1e-4))
    self.reshape1 = tf.keras.layers.Reshape(target_shape=(50, 38))
    self.softmax_output = tf.keras.layers.Softmax()

    # DROPOUT LAYERS
    self.dropout1 = tf.keras.layers.Dropout(self.dropoutrate)
    self.dropout2 = tf.keras.layers.Dropout(self.dropoutrate)
    self.dropout3 = tf.keras.layers.Dropout(self.dropoutrate)
    self.dropout4 = tf.keras.layers.Dropout(self.dropoutrate)
    self.dropout5 = tf.keras.layers.Dropout(self.dropoutrate)
    self.dropout6 = tf.keras.layers.Dropout(self.dropoutrate)
    self.dropout7 = tf.keras.layers.Dropout(self.dropoutrate)

  def call(self, inputs, training=False):
    #x = tf.keras.Input(shape=(200, 44))(inputs)
    x = inputs
    
    # LSTMS
    x = self.lstm1(x)
    x = self.lstm2(x)
    x = self.dense0(x)

    # ENCODING
    x = self.dense1(x)
    if training: x = self.dropout1(x)
    x = self.dense2(x)
    x = self.dense3(x)
    if training: x = self.dropout2(x)

    # DECODING
    x = self.dense4(x)
    x = self.dense5(x)
    if training: x = self.dropout3(x)
    x = self.dense6(x)
    x = self.dense7(x)
    if training: x = self.dropout4(x)
    x = self.dense8(x)
    x = self.dense9(x)
    if training: x = self.dropout5(x)
    x = self.dense10(x)
    x = self.dense11(x)
    if training: x = self.dropout6(x)
    x = self.dense12(x)
    if training: x = self.dropout7(x)
    x = self.dense13(x)

    # OUTPUT
    x = self.dense14(x)
    x = self.reshape1(x)
    x = self.softmax_output(x)

    return x

# %%
model = AutoEncoder()

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5, epsilon=1e-7, use_ema=True), loss=tf.keras.losses.CategoricalCrossentropy(), metrics = ['accuracy'])

# %%
model.build(train.shape)

# %%
model.summary()
# Out:
# Model: "auto_encoder_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  multiple                 171008
#  nal)
#
#  bidirectional_3 (Bidirectio  multiple                 3149824
#  nal)
#
#  dense_15 (Dense)            multiple                  131200
#
#  dense_16 (Dense)            multiple                  4128
#
#  dense_17 (Dense)            multiple                  528
#
#  dense_18 (Dense)            multiple                  272
#
#  dense_19 (Dense)            multiple                  272
#
#  dense_20 (Dense)            multiple                  272
#
#  dense_21 (Dense)            multiple                  544
#
#  dense_22 (Dense)            multiple                  2112
#
#  dense_23 (Dense)            multiple                  8320
#
#  dense_24 (Dense)            multiple                  33024
#
#  dense_25 (Dense)            multiple                  131584
#
#  dense_26 (Dense)            multiple                  525312
#
#  dense_27 (Dense)            multiple                  2099200
#
#  dense_28 (Dense)            multiple                  8392704
#
#  dense_29 (Dense)            multiple                  7784300
#
#  reshape_1 (Reshape)         multiple                  0
#
#  softmax_1 (Softmax)         multiple                  0
#
#  dropout_7 (Dropout)         multiple                  0 (unused)
#
#  dropout_8 (Dropout)         multiple                  0 (unused)
#
#  dropout_9 (Dropout)         multiple                  0 (unused)
#
#  dropout_10 (Dropout)        multiple                  0 (unused)
#
#  dropout_11 (Dropout)        multiple                  0 (unused)
#
#  dropout_12 (Dropout)        multiple                  0 (unused)
#
#  dropout_13 (Dropout)        multiple                  0 (unused)
#
# =================================================================
# Total params: 22,434,604
# Trainable params: 22,434,604
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(train[:10_000,:,:], train[:10_000, :, :], validation_split = 0.2, batch_size=4, epochs=10)
# Out:
# Epoch 1/10
# 2023-05-25 23:38:29.458146: W tensorflow/tsl/framework/bfc_allocator.cc:479] Allocator (GPU_0_bfc) ran out of memory trying to allocate 32.00MiB (rounded to 33554432)requested by op gradient_tape/dense_28/kernel/Regularizer/mul
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-05-25 23:38:29.458248: I tensorflow/tsl/framework/bfc_allocator.cc:1034] BFCAllocator dump for GPU_0_bfc
# 2023-05-25 23:38:29.458290: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (256): 	Total Chunks: 140, Chunks in use: 140. 35.0KiB allocated for chunks. 35.0KiB in use in bin. 4.1KiB client-requested in use in bin.
# 2023-05-25 23:38:29.458322: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (512): 	Total Chunks: 10, Chunks in use: 10. 6.0KiB allocated for chunks. 6.0KiB in use in bin. 5.0KiB client-requested in use in bin.
# 2023-05-25 23:38:29.458354: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (1024): 	Total Chunks: 27, Chunks in use: 27. 29.5KiB allocated for chunks. 29.5KiB in use in bin. 27.6KiB client-requested in use in bin.
# 2023-05-25 23:38:29.458384: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (2048): 	Total Chunks: 39, Chunks in use: 39. 83.5KiB allocated for chunks. 83.5KiB in use in bin. 78.0KiB client-requested in use in bin.
# 2023-05-25 23:38:29.458414: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (4096): 	Total Chunks: 10, Chunks in use: 10. 56.8KiB allocated for chunks. 56.8KiB in use in bin. 55.9KiB client-requested in use in bin.
# 2023-05-25 23:38:29.458445: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (8192): 	Total Chunks: 28, Chunks in use: 27. 247.2KiB allocated for chunks. 238.5KiB in use in bin. 215.4KiB client-requested in use in bin.
# 2023-05-25 23:38:29.458476: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (16384): 	Total Chunks: 22, Chunks in use: 22. 395.0KiB allocated for chunks. 395.0KiB in use in bin. 379.4KiB client-requested in use in bin.
# 2023-05-25 23:38:29.458507: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (32768): 	Total Chunks: 10, Chunks in use: 10. 354.2KiB allocated for chunks. 354.2KiB in use in bin. 317.7KiB client-requested in use in bin.
# 2023-05-25 23:38:29.458536: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (65536): 	Total Chunks: 13, Chunks in use: 13. 1.08MiB allocated for chunks. 1.08MiB in use in bin. 892.0KiB client-requested in use in bin.
# 2023-05-25 23:38:29.458565: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (131072): 	Total Chunks: 13, Chunks in use: 13. 1.66MiB allocated for chunks. 1.66MiB in use in bin. 1.45MiB client-requested in use in bin.
# 2023-05-25 23:38:29.458593: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (262144): 	Total Chunks: 10, Chunks in use: 9. 2.95MiB allocated for chunks. 2.65MiB in use in bin. 2.33MiB client-requested in use in bin.
# 2023-05-25 23:38:29.458623: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (524288): 	Total Chunks: 17, Chunks in use: 17. 10.15MiB allocated for chunks. 10.15MiB in use in bin. 9.06MiB client-requested in use in bin.
# 2023-05-25 23:38:29.458652: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (1048576): 	Total Chunks: 1, Chunks in use: 0. 1.78MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-05-25 23:38:29.458683: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (2097152): 	Total Chunks: 17, Chunks in use: 17. 40.17MiB allocated for chunks. 40.17MiB in use in bin. 34.00MiB client-requested in use in bin.
# 2023-05-25 23:38:29.458714: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (4194304): 	Total Chunks: 9, Chunks in use: 8. 44.64MiB allocated for chunks. 37.80MiB in use in bin. 32.00MiB client-requested in use in bin.
# 2023-05-25 23:38:29.458745: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (8388608): 	Total Chunks: 10, Chunks in use: 10. 99.83MiB allocated for chunks. 99.83MiB in use in bin. 83.60MiB client-requested in use in bin.
# 2023-05-25 23:38:29.458777: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (16777216): 	Total Chunks: 8, Chunks in use: 8. 224.31MiB allocated for chunks. 224.31MiB in use in bin. 218.02MiB client-requested in use in bin.
# 2023-05-25 23:38:29.458809: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (33554432): 	Total Chunks: 15, Chunks in use: 15. 625.32MiB allocated for chunks. 625.32MiB in use in bin. 533.40MiB client-requested in use in bin.
# 2023-05-25 23:38:29.458840: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (67108864): 	Total Chunks: 6, Chunks in use: 6. 637.31MiB allocated for chunks. 637.31MiB in use in bin. 618.10MiB client-requested in use in bin.
# 2023-05-25 23:38:29.458877: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (134217728): 	Total Chunks: 5, Chunks in use: 5. 795.52MiB allocated for chunks. 795.52MiB in use in bin. 795.52MiB client-requested in use in bin.
# 2023-05-25 23:38:29.458906: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (268435456): 	Total Chunks: 3, Chunks in use: 3. 2.84GiB allocated for chunks. 2.84GiB in use in bin. 2.84GiB client-requested in use in bin.
# 2023-05-25 23:38:29.458935: I tensorflow/tsl/framework/bfc_allocator.cc:1057] Bin for 32.00MiB was 32.00MiB, Chunk State:
# 2023-05-25 23:38:29.458959: I tensorflow/tsl/framework/bfc_allocator.cc:1070] Next region of size 5659820032
# 2023-05-25 23:38:29.458988: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fcd66000000 of size 1130804224 next 1
# 2023-05-25 23:38:29.459012: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fcda966b400 of size 1280 next 2
# 2023-05-25 23:38:29.459035: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fcda966b900 of size 904643328 next 3
# 2023-05-25 23:38:29.459061: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fcddf527c00 of size 226160896 next 4
# 2023-05-25 23:38:29.459084: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fcdeccd6d00 of size 256 next 5
# 2023-05-25 23:38:29.459106: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fcdeccd6e00 of size 256 next 9
# 2023-05-25 23:38:29.459128: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fcdeccd6f00 of size 256 next 10
# 2023-05-25 23:38:29.459150: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fcdeccd7000 of size 256 next 92
# 2023-05-25 23:38:29.459171: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fcdeccd7100 of size 256 next 12
# 2023-05-25 23:38:29.459193: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fcdeccd7200 of size 256 next 13
# 2023-05-25 23:38:29.459214: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fcdeccd7300 of size 256 next 14
# 2023-05-25 23:38:29.459236: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fcdeccd7400 of size 256 next 15
# 2023-05-25 23:38:29.459257: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fcdeccd7500 of size 256 next 17
# 2023-05-25 23:38:29.459279: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fcdeccd7600 of size 256 next 18
# 2023-05-25 23:38:29.459300: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fcdeccd7700 of size 256 next 31
# 2023-05-25 23:38:29.459322: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fcdeccd7800 of size 256 next 16
# 2023-05-25 23:38:29.459345: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fcdeccd7900 of size 256 next 19
# 2023-05-25 23:38:29.459367: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fcdeccd7a00 of size 256 next 32
# 2023-05-25 23:38:29.459389: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fcdeccd7b00 of size 256 next 34
# 2023-05-25 23:38:29.459411: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fcdeccd7c00 of size 256 next 445
# 2023-05-25 23:38:29.459433: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fcdeccd7d00 of size 256 next 45
# 2023-05-25 23:38:29.459455: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fcdeccd7e00 of size 256 next 43
# 2023-05-25 23:38:29.459478: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fcdeccd7f00 of size 256 next 25
# 2023-05-25 23:38:29.459512: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fcdecc
I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 12160000 totalling 11.60MiB
# 2023-05-25 23:39:59.683975: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 14929664 totalling 14.24MiB
# 2023-05-25 23:39:59.684001: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 15544320 totalling 14.82MiB
# 2023-05-25 23:39:59.684027: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 16777216 totalling 16.00MiB
# 2023-05-25 23:39:59.684053: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 6 Chunks of size 31129600 totalling 178.12MiB
# 2023-05-25 23:39:59.684079: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 31653888 totalling 30.19MiB
# 2023-05-25 23:39:59.684105: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 3 Chunks of size 33554432 totalling 96.00MiB
# 2023-05-25 23:39:59.684130: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 33554688 totalling 32.00MiB
# 2023-05-25 23:39:59.684156: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 33555456 totalling 32.00MiB
# 2023-05-25 23:39:59.684182: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 36081664 totalling 34.41MiB
# 2023-05-25 23:39:59.684208: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 37748736 totalling 36.00MiB
# 2023-05-25 23:39:59.684234: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 38024448 totalling 36.26MiB
# 2023-05-25 23:39:59.684259: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 41943296 totalling 40.00MiB
# 2023-05-25 23:39:59.684285: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 47906816 totalling 45.69MiB
# 2023-05-25 23:39:59.684311: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 48640000 totalling 46.39MiB
# 2023-05-25 23:39:59.684336: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 53682944 totalling 51.20MiB
# 2023-05-25 23:39:59.684363: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 2 Chunks of size 60800000 totalling 115.97MiB
# 2023-05-25 23:39:59.684389: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 62290944 totalling 59.41MiB
# 2023-05-25 23:39:59.684415: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 68519936 totalling 65.35MiB
# 2023-05-25 23:39:59.684441: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 113088000 totalling 107.85MiB
# 2023-05-25 23:39:59.684468: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 3 Chunks of size 121600000 totalling 347.90MiB
# 2023-05-25 23:39:59.684494: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 121858560 totalling 116.21MiB
# 2023-05-25 23:39:59.684520: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 4 Chunks of size 152000000 totalling 579.83MiB
# 2023-05-25 23:39:59.684546: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 226160896 totalling 215.68MiB
# 2023-05-25 23:39:59.684572: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 904643328 totalling 862.73MiB
# 2023-05-25 23:39:59.684598: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 1017716224 totalling 970.57MiB
# 2023-05-25 23:39:59.684624: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 1130804224 totalling 1.05GiB
# 2023-05-25 23:39:59.684649: I tensorflow/tsl/framework/bfc_allocator.cc:1102] Sum Total of in-use chunks: 5.27GiB
# 2023-05-25 23:39:59.684675: I tensorflow/tsl/framework/bfc_allocator.cc:1104] total_region_allocated_bytes_: 5659820032 memory_limit_: 5659820032 available bytes: 0 curr_region_allocation_bytes_: 11319640064
# 2023-05-25 23:39:59.684708: I tensorflow/tsl/framework/bfc_allocator.cc:1110] Stats:
# Limit:                      5659820032
# InUse:                      5659512320
# MaxInUse:                   5659512576
# NumAllocs:                      735382
# MaxAllocSize:               1130804224
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-05-25 23:39:59.684818: W tensorflow/tsl/framework/bfc_allocator.cc:492] ****************************************************************************************************
# 2023-05-25 23:39:59.684867: W tensorflow/core/framework/op_kernel.cc:1818] RESOURCE_EXHAUSTED: failed to allocate memory
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 hist = model.fit(train[:10_000,:,:], train[:10_000, :, :], validation_split = 0.2, batch_size=4, epochs=10)
#
# File ~/anaconda3/envs/chem/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/anaconda3/envs/chem/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node 'gradient_tape/dense_28/kernel/Regularizer/mul' defined at (most recent call last):
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#       app.start()
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 725, in start
#       self.io_loop.start()
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#       self.asyncio_loop.run_forever()
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#       self._run_once()
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#       handle._run()
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#       await self.process_one()
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#       await dispatch(*args)
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#       await result
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#       reply_content = await reply_content
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#       res = shell.run_cell(
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#       result = self._run_cell(
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#       result = runner(coro)
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/tmp/ipykernel_4574/550852192.py", line 1, in <module>
#       hist = model.fit(train[:10_000,:,:], train[:10_000, :, :], validation_split = 0.2, batch_size=4, epochs=10)
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/site-packages/keras/engine/training.py", line 1650, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/site-packages/keras/engine/training.py", line 1249, in train_function
#       return step_function(self, iterator)
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/site-packages/keras/engine/training.py", line 1233, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/site-packages/keras/engine/training.py", line 1222, in run_step
#       outputs = model.train_step(data)
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/site-packages/keras/engine/training.py", line 1027, in train_step
#       self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 526, in minimize
#       grads_and_vars = self.compute_gradients(loss, var_list, tape)
#     File "/home/diogo/anaconda3/envs/chem/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 259, in compute_gradients
#       grads = tape.gradient(loss, var_list)
# Node: 'gradient_tape/dense_28/kernel/Regularizer/mul'
# failed to allocate memory
# 	 [[{{node gradient_tape/dense_28/kernel/Regularizer/mul}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_30646]

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
